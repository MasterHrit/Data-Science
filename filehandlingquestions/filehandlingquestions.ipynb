# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.
#
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.
#
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.
#
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.
#
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.
#
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.
#
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.
#
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.
#
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.
#
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.
#
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.
#
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.
#
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.
#
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.
#
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
### Assignment 1: Reading a File

# Write a function that reads the contents of a file named `sample.txt` and prints each line.
with open("sample.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# Hello Everyone
# My Name is Hritik Kumar Agarwal
# Today I am here to Learn Machine Learning
# But Before that I need to strengthen my Python Language and Data Analysis

# %%
### Assignment 2: Writing to a File

# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.
s=["My Name is Hritik","I am learning Python","I am planning to learn ML thoroughly"]
with open("output.txt","w") as file:
    for i in s:
        file.write(i+"\n")

# %%
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

with open("output.txt","r") as filesource:
    content=filesource.read()
    with open("destination.txt","w") as destfile:
        destfile.write(content)

# %%
# Write a function that appends a given string to the end of a file named `log.txt`.
s="Error Log"
with open("log.txt","a") as logfile:
    logfile.write(s+"\n")

# %%
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.
count=0
with open("sample.txt","r") as file:
    lines=file.readlines()
    for line in lines:
        count+=len(line.strip().split(" "))
        print(line.strip().split(" "))
    print(count)
# Out:
# ['Hello', 'Everyone']
# ['My', 'Name', 'is', 'Hritik', 'Kumar', 'Agarwal']
# ['Today', 'I', 'am', 'here', 'to', 'Learn', 'Machine', 'Learning']
# ['But', 'Before', 'that', 'I', 'need', 'to', 'strengthen', 'my', 'Python', 'Language', 'and', 'Data', 'Analysis']
# 29

# %%
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.
with open("sample.txt","r") as file:
    content=file.read()
    content=content.replace("I","You")
    with open("data.txt","w") as writefile:
        writefile.write(content)

# %%
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.
with open("sample.txt","r") as file:
    lines=file.readlines()
    for line in lines:
        wordlist=line.strip().split(" ")
        reversewordlist=wordlist[::-1]
        print(" ".join(reversewordlist))
# Out:
# Everyone Hello
# Agarwal Kumar Hritik is Name My
# Learning Machine Learn to here am I Today
# Analysis Data and Language Python my strengthen to need I that Before But

# %%
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.
with open("stats.txt","r") as file:
    content=file.read()
    print("No of Words :",len(content.split(" ")))
    file.seek(0,0)
    lineslist=file.readlines()
    print("No of Lines :",len(lineslist))
    count=0
    for line in lineslist:
        count+=len(line.strip())
        print(line.strip())
    print("Character Count :",count)
# Out:
# No of Words : 17
# No of Lines : 3
# I could have taken up that opportunity as well
# Its part of learning taking up challenges
# It is okay.
# Character Count : 98

# %%
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.
filelist=["example1.txt","example2.txt","example3.txt"]
with open("merged.txt","w") as mergefile:
    for file in filelist:
        with open(file,"r") as readfile:
            mergefile.write(readfile.read()+"\n")

# %%
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.
import math
with open("large.txt","r") as largefile:
    lineslist=largefile.readlines()
    for i in range(1,math.ceil(len(lineslist)/100)):
        with open("test"+str(i),"w") as smallfiles:
            smallfiles.writelines(lineslist[i*100:i*100+100])

# %%
import math
print(math.ceil(1))
print(math.ceil(1.2))
print(math.ceil(2))
print(math.ceil(1.6))
# Out:
# 1
# 2
# 2
# 2

# %%
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.
import datetime
with open("activity.log","w") as file:
    timestamp=datetime.datetime.now().isoformat()
    file.write(f'[{timestamp}] {"Logging Now!!"}\n')

# %%
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

with open("image.bin","rb") as file:
    content=file.read()
    with open("copy_image.bin","wb") as writefile:
        writefile.write(content)

# %%
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.
import csv

with open("MOCK_DATA.csv","r") as file:
    reader=csv.DictReader(file)
    print(list(reader))
# Out:
# [{'id': '1', 'first_name': 'Damiano', 'last_name': 'Coultar', 'email': 'dcoultar0@canalblog.com', 'gender': 'Male', 'ip_address': '142.157.223.82'}, {'id': '2', 'first_name': 'Violetta', 'last_name': 'Gierok', 'email': 'vgierok1@dot.gov', 'gender': 'Female', 'ip_address': '249.211.236.50'}, {'id': '3', 'first_name': 'Ewen', 'last_name': 'Covely', 'email': 'ecovely2@buzzfeed.com', 'gender': 'Polygender', 'ip_address': '207.116.255.109'}, {'id': '4', 'first_name': 'Aggie', 'last_name': 'Villiers', 'email': 'avilliers3@nature.com', 'gender': 'Female', 'ip_address': '195.60.99.52'}, {'id': '5', 'first_name': 'Alethea', 'last_name': 'Ilyas', 'email': 'ailyas4@ehow.com', 'gender': 'Female', 'ip_address': '180.54.250.245'}, {'id': '6', 'first_name': 'Chalmers', 'last_name': 'Colvie', 'email': 'ccolvie5@aboutads.info', 'gender': 'Male', 'ip_address': '131.144.104.234'}, {'id': '7', 'first_name': 'Donn', 'last_name': 'Warrilow', 'email': 'dwarrilow6@ucsd.edu', 'gender': 'Male', 'ip_address': 
# ...

# %%
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.
import json

with open("data.json","r") as file:
    data=json.load(file)
    print(data)
# Out:
# {'name': 'Hritik', 'age': 24, 'marks': [81, 92, 83, 94]}

# %%
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

try:
    with open("protected.txt","r") as file:
        data=file.read()
        print(data)
except FileNotFoundError as e:
    print(f"Error Message : {e}")
# Out:
# Error Message : [Errno 2] No such file or directory: 'protected.txt'
